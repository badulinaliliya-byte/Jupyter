# %%
# Задача. Создайте файл task.ipynb и напишите код, который:
# - Вычисляет сумму двух чисел.
# - Находит среднее арифметическое трех чисел.
# - Выводит квадрат заданного числа.
# - Запустите код и сохраните .ipynb файл.
a1 = int(input ("Введите первое целое число: "))
b1 = int(input ("Введите второе целое число: "))
print(f"Сумма введенных чисел: {a1 + b1}")
a2 = int(input ("Введите первое целое число: "))
b2 = int(input ("Введите второе целое число: "))
c2 = int(input ("Введите третье целое число: "))
print(f"Среднее арифметическое 3-х чисел: {(a2 + b2 + c2)/3:.2f}")
a3 = int(input ("Введите целое число: "))
print(f"Квадрат указанного числа: {a3 ** 2}")
# Out:
# Сумма введенных чисел: 8
# Среднее арифметическое 3-х чисел: 7.67
# Квадрат указанного числа: 16
